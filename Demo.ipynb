# %%
from routemodel import RouteModel

# %%
# Start and end point - Demo #1
start = (34.045520, -118.208998)
end = (34.074007, -118.341765)
center = ((start[0]+end[0])/2, (start[1]+end[1])/2)

# %%
# Start and end point - Demo #2
start = (34.223756, -118.526886)
end = (34.045628, -118.423420)
center = ((start[0]+end[0])/2, (start[1]+end[1])/2)

# %%
test = RouteModel(start_latlong=start,end_latlong=end,route_safety_importance=0.0)

# %%
test.plot_two_routes()
# Out:
# Shortest Path Length: 27245.89200000001
# Safer Path Length: 27101.942000000006
